# %%
# import panda
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv")
df = pd.read_csv("titanic.csv")
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
# df.to_csv("titanic.csv")

# %%
# survival - Survival (0 = No; 1 = Yes)
# class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# name - Name
# sex - Sex
# age - Age
# sibsp - Number of Siblings/Spouses Aboard
# parch - Number of Parents/Children Aboard
# ticket - Ticket Number
# fare - Passenger Fare
# cabin - Cabin
# embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.head(20)
# Out:
#     Unnamed: 0  PassengerId  Survived  Pclass  \
# 0            0            1         0       3
# 1            1            2         1       1
# 2            2            3         1       3
# 3            3            4         1       1
# 4            4            5         0       3
# 5            5            6         0       3
# 6            6            7         0       1
# 7            7            8         0       3
# 8            8            9         1       3
# 9            9           10         1       2
# 10          10           11         1       3
# 11          11           12         1       1
# 12          12           13         0       3
# 13          13           14         0       3
# 14          14           15         0       3
# 15          15           16         1       2
# 16          16           17         0       3
# 17          17           18         1       2
# 18          18           19         0       3
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 886                     Montvila, Rev. Juozas    male  27.0      0      0
# 887              Graham, Miss. Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                     Behr, Mr. Karl Howell    male  26.0      0      0
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 886      211536  13.00   NaN        S
# 887      112053  30.00   B42        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %%
df.tail(10)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 881         881          882         0       3
# 882         882          883         0       3
# 883         883          884         0       2
# 884         884          885         0       3
# 885         885          886         0       3
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 881                        Markun, Mr. Johann    male  33.0      0      0
# 882              Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 883             Banfield, Mr. Frederick James    male  28.0      0      0
# 884                    Sutehall, Mr. Henry Jr    male  25.0      0      0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Pclass'] # Series Dataset
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df = df[['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
       'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[['Name', 'Age', 'Pclass', 'Fare']][df['Name'] == "Sutehall, Mr. Henry Jr"]
# Out:
#                        Name   Age  Pclass  Fare
# 884  Sutehall, Mr. Henry Jr  25.0       3  7.05

# %%
df[['Name', 'Age', 'Pclass', 'Fare']][df['Age'] == 30]
# Out:
#                                                   Name   Age  Pclass      Fare
# 79                            Dowdell, Miss. Elizabeth  30.0       3   12.4750
# 157                                    Corn, Mr. Harry  30.0       3    8.0500
# 178                                 Hale, Mr. Reginald  30.0       2   13.0000
# 213                        Givard, Mr. Hans Kristensen  30.0       2   13.0000
# 219                                 Harris, Mr. Walter  30.0       2   10.5000
# 244                               Attalah, Mr. Sleiman  30.0       3    7.2250
# 253                           Lobb, Mr. William Arthur  30.0       3   16.1000
# 257                               Cherry, Miss. Gladys  30.0       1   86.5000
# 286                            de Mulder, Mr. Theodore  30.0       3    9.5000
# 308                                Abelson, Mr. Samuel  30.0       2   24.0000
# 309                     Francatelli, Miss. Laura Mabel  30.0       1   56.9292
# ...

# %%
df[['Name', 'Age', 'Pclass', 'Fare']][df['Age'] == 30].count()
# Out:
# Name      25
# Age       25
# Pclass    25
# Fare      25
# dtype: int64

# %%
df[['Name', 'Age', 'Pclass', 'Fare']][df['Age'] >= 30]
# Out:
#                                                   Name   Age  Pclass     Fare
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1  71.2833
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1  53.1000
# 4                             Allen, Mr. William Henry  35.0       3   8.0500
# 6                              McCarthy, Mr. Timothy J  54.0       1  51.8625
# 11                            Bonnell, Miss. Elizabeth  58.0       1  26.5500
# ..                                                 ...   ...     ...      ...
# 873                        Vander Cruyssen, Mr. Victor  47.0       3   9.0000
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0       1  83.1583
# 881                                 Markun, Mr. Johann  33.0       3   7.8958
# 885               Rice, Mrs. William (Margaret Norton)  39.0       3  29.1250
# 890                                Dooley, Mr. Patrick  32.0       3   7.7500
#
# [330 rows x 4 columns]

# %%
df[['Name', 'Age', 'Pclass', 'Fare']][(df['Age'] >= 30) & (df['Age'] >= 40)]
# Out:
#                                                   Name   Age  Pclass     Fare
# 6                              McCarthy, Mr. Timothy J  54.0       1  51.8625
# 11                            Bonnell, Miss. Elizabeth  58.0       1  26.5500
# 15                    Hewlett, Mrs. (Mary D Kingcome)   55.0       2  16.0000
# 30                            Uruchurtu, Don. Manuel E  40.0       1  27.7208
# 33                               Wheadon, Mr. Edward H  66.0       2  10.5000
# ..                                                 ...   ...     ...      ...
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  48.0       1  25.9292
# 865                           Bystrom, Mrs. (Karolina)  42.0       2  13.0000
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0       1  52.5542
# 873                        Vander Cruyssen, Mr. Victor  47.0       3   9.0000
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0       1  83.1583
#
# [163 rows x 4 columns]

# %%
df['Age'].dtype
# Out:
# dtype('float64')

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
sorted(df['Age'])
# Out:
# [2.0,
#  2.0,
#  3.0,
#  4.0,
#  7.0,
#  8.0,
#  14.0,
#  14.0,
#  14.0,
#  15.0,
#  18.0,
#  18.0,
#  19.0,
#  19.0,
#  20.0,
#  21.0,
#  21.0,
#  22.0,
#  26.0,
#  27.0,
#  27.0,
#  28.0,
#  28.0,
#  29.0,
#  31.0,
#  34.0,
#  35.0,
#  35.0,
#  38.0,
#  nan,
#  35.0,
#  38.0,
#  39.0,
#  40.0,
#  40.0,
#  42.0,
#  54.0,
#  55.0,
#  58.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  66.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  49.0,
#  65.0,
#  nan,
#  0.83,
#  4.0,
#  5.0,
#  11.0,
#  14.5,
#  16.0,
#  16.0,
#  17.0,
#  17.0,
#  19.0,
#  20.0,
#  21.0,
#  21.0,
#  21.0,
#  21.0,
#  22.0,
#  22.0,
#  23.0,
#  23.0,
#  24.0,
#  25.0,
#  26.0,
#  28.0,
#  28.0,
#  28.0,
#  28.5,
#  33.0,
#  34.0,
#  38.0,
#  45.0,
#  nan,
#  nan,
#  26.0,
#  26.0,
#  29.0,
#  29.0,
#  29.0,
#  30.0,
#  32.0,
#  32.0,
#  nan,
#  nan,
#  nan,
#  33.0,
#  nan,
#  37.0,
#  38.0,
#  46.0,
#  59.0,
#  nan,
#  34.0,
#  71.0,
#  nan,
#  nan,
#  nan,
#  1.0,
#  2.0,
#  9.0,
#  9.0,
# ...

# %%
df['Age'][10:20]
# Out:
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# Name: Age, dtype: float64

# %%
df[1:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df[::-1]
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Boat'] = np.NAN

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Boat
# 0      0         A/5 21171   7.2500   NaN        S   NaN
# 1      0          PC 17599  71.2833   C85        C   NaN
# 2      0  STON/O2. 3101282   7.9250   NaN        S   NaN
# 3      0            113803  53.1000  C123        S   NaN
# ...

# %%
df2['Boat'] = np.random.randint(1, 27, df.shape[0]) 
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Boat
# 0      0         A/5 21171   7.2500   NaN        S    24
# 1      0          PC 17599  71.2833   C85        C     4
# 2      0  STON/O2. 3101282   7.9250   NaN        S    22
# 3      0            113803  53.1000  C123        S    17
# ...

# %%
df.drop(['Boat'], inplace=True, axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
gender = pd.get_dummies(df2['Sex'], drop_first=True)
gender
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
df2 = pd.concat([df2, gender], axis=1)

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Boat  male
# 0      0         A/5 21171   7.2500   NaN        S    24     1
# 1      0          PC 17599  71.2833   C85        C     4     0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    22     0
# ...

# %%
df2.drop(['Sex'], inplace=True, axis=1)
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Boat  male
# 0         A/5 21171   7.2500   NaN        S    24     1
# 1          PC 17599  71.2833   C85        C     4     0
# 2  STON/O2. 3101282   7.9250   NaN        S    22     0
# 3            113803  53.1000  C123        S    17     0
# ...

# %%
df2.rename(columns={'male':'Gender'}, inplace=True)
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Boat  Gender
# 0         A/5 21171   7.2500   NaN        S    24       1
# 1          PC 17599  71.2833   C85        C     4       0
# 2  STON/O2. 3101282   7.9250   NaN        S    22       0
# 3            113803  53.1000  C123        S    17       0
# ...

# %%
df2.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], inplace=True, axis=1)
df2.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare Embarked  Boat  Gender
# 0         0       3  22.0      1      0   7.2500        S    24       1
# 1         1       1  38.0      1      0  71.2833        C     4       0
# 2         1       3  26.0      0      0   7.9250        S    22       0
# 3         1       1  35.0      1      0  53.1000        S    17       0
# 4         0       3  35.0      0      0   8.0500        S     3       1
